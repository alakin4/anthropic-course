# %%
from dotenv import load_dotenv
from IPython.display import Markdown
from anthropic import Anthropic
from src.utils.chat import (
    add_user_message,
    add_assistant_message,
    chat,
    chat_with_system_prompt,
)

load_dotenv()
# Out:
# True

# %%
client = Anthropic()
model = "claude-sonnet-4-6"

# %%
messages = []
add_user_message(messages, "Generate a one sentence movie idea")
answer = chat_with_system_prompt(
    client, model=model, messages=messages, temperature=0.0
)
Markdown(answer)
# Out:
# Here's a movie idea:
#
# **A retired safecracker with early-onset dementia must break into a high-security vault before his memory fades completely — because the only cure for his condition is locked inside.

# %%
messages = []
add_user_message(messages, "Generate a one sentence movie idea")
answer = chat_with_system_prompt(
    client, model=model, messages=messages, temperature=0.0
)
Markdown(answer)
# Out:
# Here's a movie idea:
#
# **A retired safecracker with early-onset Alzheimer's must pull off one final heist before he forgets the combination to the vault — and who he is.**

# %%
# Increase temperature to 1.0 for more creative responses. Temperate of 1 should
# give more varying responses---ofcourse not always the case, but in general you should see more variation in the responses.
messages = []
add_user_message(messages, "Generate a one sentence movie idea")
answer = chat_with_system_prompt(
    client, model=model, messages=messages, temperature=1.0
)
Markdown(answer)
# Out:
# Here's a movie idea:
#
# **A retired safecracker with early-onset Alzheimer's must pull off one final heist before he forgets the combination to the vault that holds the only evidence that can save his wrongfully convicted son.**
